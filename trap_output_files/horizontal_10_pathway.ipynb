# %%
import sys
import logging, os
from time import time
import numpy as np
import pyvista as pv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
# %matplotlib notebook

from bem import Electrodes, Sphere, Cylinder, Mesh, Grid, Configuration, Result
from bem.formats import stl

# %% [markdown]
# # Import mesh from stl

# %%
# base file name for outputs and inputs is the script name
try:
    # works only if we are a script
    prefix = os.path.splitext(__file__)[0]
except NameError:
    # fallback for notebooks
    prefix = "horizontal_10_pathway_mirror_inventor"
suffix = ""

# %%
scale = 100e-6    # Distance from ion to electrode is 40 um.
use_stl = True

# load electrode faces from colored stl
# s_nta is intermediate processed stl file.
s_nta = stl.read_stl(open("%s.stl" % prefix, "rb"))
print("Import stl:",os.path.abspath("./"+prefix+".stl"),"\n")
print("Electrode colors (numbers):\n")
mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=scale/1e-6,rename={1:"1"}))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       2 use_stl = True
#       4 # load electrode faces from colored stl
#       5 # s_nta is intermediate processed stl file.
# ----> 6 s_nta = stl.read_stl(open("%s.stl" % prefix, "rb"))
#       7 print("Import stl:",os.path.abspath("./"+prefix+".stl"),"\n")
#       8 print("Electrode colors (numbers):\n")
#
# File ~/anaconda3/envs/paulanalysis/lib/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'horizontal_10_pathway_mirror_inventor.stl'

# %%
print(len(s_nta), type(s_nta),"\n")
# s_nta is a length 3 tuple. (normal, triangle, attribute) 
# Normal direction of each triangle, three vetice of triangles, coding number of colors.
print("Triangles:",len(s_nta[0]),"\nColors:",len(s_nta[2]),"\n")    # This isn't right.

# stl_to_mesh() only assigns names and does scaling, doing no triangulation to stl mesh.
# "scale=scale/1e-6" only scales dimensionless scale/1e-6.    1e-6: if stl uses micron as unit. 
mesh = Mesh.from_mesh(stl.stl_to_mesh(*s_nta, scale=scale/1e-6,
    rename={
        20960:"DC0",
        28165:"DC1",
        21:"DC2",
        3195:"DC3",
        24603:"DC4",
        1530:"DC5",
        24063:"DC6",
        1882:"DC7",
        30850:"DC8",
        8456:"DC9",
        7725:"DC10",
        1633:"DC11",
        23887:"DC12",
        21340:"DC13",
        24233:"DC14",
        565:"DC15",
        26323:"DC16",
        30653:"RF1",
        0:"RF2",
#         20083:"discard",
           }))
# Out:
# 3 <class 'tuple'>
#
# Triangles: 11444
# Colors: 11444
#
# dropping 20083

# %%
mesh.plot()

# %%
# set .1 max area within 3
# areas_from_constraints specifies sphere with finer mesh inside it.
mesh.areas_from_constraints(Sphere(center=np.array([0., 1.92, 0]),
           radius=5, inside=0.05, outside=10.))    # "inside", "outside" set different mesh densities.
# mesh.areas_from_constraints(Sphere(center=np.array([0., 0., 1]),
#            radius=3.5, inside=0.1, outside=5))    # "inside", "outside" set different mesh densities.
# retriangulate quality and quiet with areas
mesh.triangulate(opts="q20Q", new=False)
# save base mesh to vtk
mesh.to_vtk(prefix+suffix)
print("Output vtk:",os.path.abspath("./"+prefix+suffix+".vtk"))    # output path

# fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"), figsize=(8,6), dpi=100)
# ax.set_xlabel("x/l",fontsize=10)
# ax.set_ylabel("y/l",fontsize=10)
# mesh.plot(ax)
# Out:
# start triangulate DC1
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC1
# start triangulate DC7
# final opts q20Qzra
# finish triangulate DC7
# start triangulate DC5
# final opts q20Qzra
# finish triangulate DC5
# start triangulate DC13
# final opts q20Qzra
# finish triangulate DC13
# start triangulate RF2
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate RF2
# start triangulate DC11
# final opts q20Qzra
# finish triangulate DC11
# start triangulate DC10
# final opts q20Qzra
# finish triangulate DC10
# start triangulate RF1
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate RF1
# start triangulate DC4
# final opts q20Qzra
# finish triangulate DC4
# start triangulate DC6
# final opts q20Qzra
# finish triangulate DC6
# start triangulate DC8
# final opts q20Qzra
# finish triangulate DC8
# start triangulate DC12
# final opts q20Qzra
# finish triangulate DC12
# start triangulate DC9
# final opts q20Qzra
# finish triangulate DC9
# start triangulate DC3
# final opts q20Qzra
# finish triangulate DC3
# start triangulate DC14
# final opts q20Qzra
# finish triangulate DC14
# start triangulate DC16
# final opts q20Qzra
# finish triangulate DC16
# start triangulate DC15
# final opts q20Qzra
# finish triangulate DC15
# start triangulate DC2
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC2
# start triangulate DC0
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# final opts q20Qzra
# finish triangulate DC0
# Output vtk: C:\Users\3d_printing\Documents\TrapSimulation\horizontal_10_pathway_mirror_inventor\horizontal_10_pathway_mirror_inventor.vtk

# %%
mesh.plot()

# %%
Result.view(prefix, '')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
mesh, _=Mesh.from_vtk('vtks/horizontal_10_pathway_mirror_inventor')
mesh
# Out:
# Mesh([(np.str_('DC1'),
#        [<bem.triangulation.Triangulation at 0x119c5cd30>,
#         <bem.triangulation.Triangulation at 0x15e513fa0>,
#         <bem.triangulation.Triangulation at 0x15e513f40>,
#         <bem.triangulation.Triangulation at 0x15e4f3be0>,
#         <bem.triangulation.Triangulation at 0x15e4f3dc0>,
#         <bem.triangulation.Triangulation at 0x15f726040>,
#         <bem.triangulation.Triangulation at 0x15f726100>,
#         <bem.triangulation.Triangulation at 0x15f7261c0>,
#         <bem.triangulation.Triangulation at 0x15f726280>,
#         <bem.triangulation.Triangulation at 0x15f726340>,
#         <bem.triangulation.Triangulation at 0x15f726400>,
#         <bem.triangulation.Triangulation at 0x15f7264c0>,
#         <bem.triangulation.Triangulation at 0x15f726580>,
#         <bem.triangulation.Triangulation at 0x15f726640>,
#         <bem.triangulation.Triangulation at 0x15f726700>,
#         <bem.triangulation.Triangulation at 0x15f7267c0>,
#         <bem.triangulation.Triangulation at 0x15f726880>,
#         <bem.triangulation.Triangulation at 0x15f726940>,
#         <bem.triangulation.Triangulation at 0x15f726a00>,
#         <bem.triangulation.Triangulation at 0x15f726ac0>,
#         <bem.triangulation.Triangulation at 0x15f726b80>,
#         <bem.triangulation.Triangulation at 0x15f726c40>,
#         <bem.triangulation.Triangulation at 0x15f726d00>,
#         <bem.triangulation.Triangulation at 0x15f726dc0>,
#         <bem.triangulation.Triangulation at 0x15f726e80>,
#         <bem.triangulation.Triangulation at 0x15f726f40>,
#         <bem.triangulation.Triangulation at 0x15f71a040>,
#         <bem.triangulation.Triangulation at 0x15f71a100>,
#         <bem.triangulation.Triangulation at 0x15f71a1c0>,
#         <bem.triangulation.Triangulation at 0x15f71a280>,
#         <bem.triangulation.Triangulation at 0x15f71a340>,
#         <bem.triangulation.Triangulation at 0x15f71a400>,
#         <bem.triangulation.Triangulation at 0x15f71a4c0>,
#         <bem.triangulation.Triangulation at 0x15f71a580>,
#         <bem.triangulation.Triangulation at 0x15f71a640>,
#         <bem.triangulation.Triangulation at 0x15f71a700>,
#         <bem.triangulation.Triangulation at 0x15f71a7c0>,
#         <bem.triangulation.Triangulation at 0x15f71a880>]),
#       (np.str_('DC7'), [<bem.triangulation.Triangulation at 0x15f71a940>]),
#       (np.str_('DC5'), [<bem.triangulation.Triangulation at 0x15f71aa00>]),
#       (np.str_('DC13'), [<bem.triangulation.Triangulation at 0x15f71aac0>]),
#       (np.str_('RF2'),
#        [<bem.triangulation.Triangulation at 0x15f71ab80>,
#         <bem.triangulation.Triangulation at 0x15f71ac40>,
#         <bem.triangulation.Triangulation at 0x15f71ad00>,
#         <bem.triangulation.Triangulation at 0x15f71adc0>,
#         <bem.triangulation.Triangulation at 0x15f71ae80>,
#         <bem.triangulation.Triangulation at 0x15f71af40>,
#         <bem.triangulation.Triangulation at 0x15f71e040>,
#         <bem.triangulation.Triangulation at 0x15f71e100>,
#         <bem.triangulation.Triangulation at 0x15f71e1c0>,
#         <bem.triangulation.Triangulation at 0x15f71e280>,
#         <bem.triangulation.Triangulation at 0x15f71e340>,
#         <bem.triangulation.Triangulation at 0x15f71e400>,
#         <bem.triangulation.Triangulation at 0x15f71e4c0>,
#         <bem.triangulation.Triangulation at 0x15f71e580>,
#         <bem.triangulation.Triangulation at 0x15f71e640>,
#         <bem.triangulation.Triangulation at 0x15f71e700>,
#         <bem.triangulation.Triangulation at 0x15f71e7c0>,
#         <bem.triangulation.Triangulation at 0x15f71e880>,
#         <bem.triangulation.Triangulation at 0x15f71e940>,
#         <bem.triangulation.Triangulation at 0x15f71ea00>,
#         <bem.triangulation.Triangulation at 0x15f71eac0>,
#         <bem.triangulation.Triangulation at 0x15f71eb80>,
#         <bem.triangulation.Triangulation at 0x15f71ec40>,
#         <bem.triangulation.Triangulation at 0x15f71ed00>,
#         <bem.triangulation.Triangulation at 0x15f71edc0>,
#         <bem.triangulation.Triangulation at 0x15f71ee80>,
#         <bem.triangulation.Triangulation at 0x15f71ef40>,
#         <bem.triangulation.Triangulation at 0x15f721040>,
#         <bem.triangulation.Triangulation at 0x15f721100>,
#         <bem.triangulation.Triangulation at 0x15f7211c0>,
#         <bem.triangulation.Triangulation at 0x15f721280>,
#         <bem.triangulation.Triangulation at 0x15f721340>,
#         <bem.triangulation.Triangulation at 0x15f721400>,
#         <bem.triangulation.Triangulation at 0x15f7214c0>,
#         <bem.triangulation.Triangulation at 0x15f721580>,
#         <bem.triangulation.Triangulation at 0x15f721640>,
#         <bem.triangulation.Triangulation at 0x15f721700>,
#         <bem.triangulation.Triangulation at 0x15f7217c0>,
#         <bem.triangulation.Triangulation at 0x15f721880>,
#         <bem.triangulation.Triangulation at 0x15f721940>,
#         <bem.triangulation.Triangulation at 0x15f721a00>,
#         <bem.triangulation.Triangulation at 0x15f721ac0>,
#         <bem.triangulation.Triangulation at 0x15f721b80>,
#         <bem.triangulation.Triangulation at 0x15f721c40>]),
#       (np.str_('DC11'), [<bem.triangulation.Triangulation at 0x15f721d00>]),
#       (np.str_('DC10'), [<bem.triangulation.Triangulation at 0x15f721dc0>]),
#       (np.str_('RF1'),
#        [<bem.triangulation.Triangulation at 0x15f721e80>,
#         <bem.triangulation.Triangulation at 0x15f721f40>,
#         <bem.triangulation.Triangulation at 0x15f725040>,
#         <bem.triangulation.Triangulation at 0x15f725100>,
#         <bem.triangulation.Triangulation at 0x15f7251c0>,
#         <bem.triangulation.Triangulation at 0x15f725280>,
#         <bem.triangulation.Triangulation at 0x15f725340>,
#         <bem.triangulation.Triangulation at 0x15f725400>,
#         <bem.triangulation.Triangulation at 0x15f7254c0>,
#         <bem.triangulation.Triangulation at 0x15f725580>,
#         <bem.triangulation.Triangulation at 0x15f725640>,
#         <bem.triangulation.Triangulation at 0x15f725700>,
#         <bem.triangulation.Triangulation at 0x15f7257c0>,
#         <bem.triangulation.Triangulation at 0x15f725880>,
#         <bem.triangulation.Triangulation at 0x15f725940>,
#         <bem.triangulation.Triangulation at 0x15f725a00>,
#         <bem.triangulation.Triangulation at 0x15f725ac0>,
#         <bem.triangulation.Triangulation at 0x15f725b80>,
#         <bem.triangulation.Triangulation at 0x15f725c40>,
#         <bem.triangulation.Triangulation at 0x15f725d00>,
#         <bem.triangulation.Triangulation at 0x15f725dc0>,
#         <bem.triangulation.Triangulation at 0x15f725e80>,
#         <bem.triangulation.Triangulation at 0x15f725f40>,
#         <bem.triangulation.Triangulation at 0x15f729040>,
#         <bem.triangulation.Triangulation at 0x15f729100>,
#         <bem.triangulation.Triangulation at 0x15f7291c0>,
#         <bem.triangulation.Triangulation at 0x15f729280>,
#         <bem.triangulation.Triangulation at 0x15f729340>,
#         <bem.triangulation.Triangulation at 0x15f729400>,
#         <bem.triangulation.Triangulation at 0x15f7294c0>,
#         <bem.triangulation.Triangulation at 0x15f729580>,
#         <bem.triangulation.Triangulation at 0x15f729640>,
#         <bem.triangulation.Triangulation at 0x15f729700>,
#         <bem.triangulation.Triangulation at 0x15f7297c0>,
#         <bem.triangulation.Triangulation at 0x15f729880>,
#         <bem.triangulation.Triangulation at 0x15f729940>,
#         <bem.triangulation.Triangulation at 0x15f729a00>,
#         <bem.triangulation.Triangulation at 0x15f729ac0>,
#         <bem.triangulation.Triangulation at 0x15f729b80>,
#         <bem.triangulation.Triangulation at 0x15f729c40>,
#         <bem.triangulation.Triangulation at 0x15f729d00>,
#         <bem.triangulation.Triangulation at 0x15f729dc0>,
#         <bem.triangulation.Triangulation at 0x15f729e80>,
#         <bem.triangulation.Triangulation at 0x15f729f40>,
#         <bem.triangulation.Triangulation at 0x15f72b040>]),
#       (np.str_('DC4'), [<bem.triangulation.Triangulation at 0x15f72b100>]),
#       (np.str_('DC6'), [<bem.triangulation.Triangulation at 0x15f72b1c0>]),
#       (np.str_('DC8'), [<bem.triangulation.Triangulation at 0x15f72b280>]),
#       (np.str_('DC12'), [<bem.triangulation.Triangulation at 0x15f72b340>]),
#       (np.str_('DC9'), [<bem.triangulation.Triangulation at 0x15f72b400>]),
#       (np.str_('DC3'), [<bem.triangulation.Triangulation at 0x15f72b4c0>]),
#       (np.str_('DC14'), [<bem.triangulation.Triangulation at 0x15f72b580>]),
#       (np.str_('DC16'), [<bem.triangulation.Triangulation at 0x15f72b640>]),
#       (np.str_('DC15'), [<bem.triangulation.Triangulation at 0x15f72b700>]),
#       (np.str_('DC2'),
#        [<bem.triangulation.Triangulation at 0x15f72b7c0>,
#         <bem.triangulation.Triangulation at 0x15f72b880>,
#         <bem.triangulation.Triangulation at 0x15f72b940>,
#         <bem.triangulation.Triangulation at 0x15f72ba00>,
#         <bem.triangulation.Triangulation at 0x15f72bac0>,
#         <bem.triangulation.Triangulation at 0x15f72bb80>,
#         <bem.triangulation.Triangulation at 0x15f72bc40>,
#         <bem.triangulation.Triangulation at 0x15f72bd00>,
#         <bem.triangulation.Triangulation at 0x15f72bdc0>,
#         <bem.triangulation.Triangulation at 0x15f72be80>,
#         <bem.triangulation.Triangulation at 0x15f72bf40>,
#         <bem.triangulation.Triangulation at 0x15f72e040>,
#         <bem.triangulation.Triangulation at 0x15f72e100>,
#         <bem.triangulation.Triangulation at 0x15f72e1c0>,
#         <bem.triangulation.Triangulation at 0x15f72e280>,
#         <bem.triangulation.Triangulation at 0x15f72e340>,
#         <bem.triangulation.Triangulation at 0x15f72e400>,
#         <bem.triangulation.Triangulation at 0x15f72e4c0>,
#         <bem.triangulation.Triangulation at 0x15f72e580>,
#         <bem.triangulation.Triangulation at 0x15f72e640>,
#         <bem.triangulation.Triangulation at 0x15f72e700>,
#         <bem.triangulation.Triangulation at 0x15f72e7c0>,
#         <bem.triangulation.Triangulation at 0x15f72e880>,
#         <bem.triangulation.Triangulation at 0x15f72e940>,
#         <bem.triangulation.Triangulation at 0x15f72ea00>,
#         <bem.triangulation.Triangulation at 0x15f72eac0>,
#         <bem.triangulation.Triangulation at 0x15f72eb80>,
#         <bem.triangulation.Triangulation at 0x15f72ec40>,
#         <bem.triangulation.Triangulation at 0x15f72ed00>,
#         <bem.triangulation.Triangulation at 0x15f72edc0>,
#         <bem.triangulation.Triangulation at 0x15f72ee80>,
#         <bem.triangulation.Triangulation at 0x15f72ef40>,
#         <bem.triangulation.Triangulation at 0x15f732040>,
#         <bem.triangulation.Triangulation at 0x15f732100>,
#         <bem.triangulation.Triangulation at 0x15f7321c0>,
#         <bem.triangulation.Triangulation at 0x15f732280>,
#         <bem.triangulation.Triangulation at 0x15f732340>,
#         <bem.triangulation.Triangulation at 0x15f732400>]),
#       (np.str_('DC0'),
#        [<bem.triangulation.Triangulation at 0x15f7324c0>,
#         <bem.triangulation.Triangulation at 0x15f732580>,
#         <bem.triangulation.Triangulation at 0x15f732640>,
#         <bem.triangulation.Triangulation at 0x15f732700>,
#         <bem.triangulation.Triangulation at 0x15f7327c0>,
#         <bem.triangulation.Triangulation at 0x15f732880>,
#         <bem.triangulation.Triangulation at 0x15f732940>,
#         <bem.triangulation.Triangulation at 0x15f732a00>,
#         <bem.triangulation.Triangulation at 0x15f732ac0>,
#         <bem.triangulation.Triangulation at 0x15f732b80>])])

# %%
mesh.plot()
